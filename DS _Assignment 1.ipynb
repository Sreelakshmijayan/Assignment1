# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to Python Environment

# %%
data=pd.read_csv('D:\python programming\_data\iris.csv')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display Columns in the Dataset

# %%
data=pd.read_csv('D:\python programming\_data\iris.csv')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # 3. Calculate the Mean of each Column of the Dataset

# %%
data=pd.read_csv('D:\python programming\_data\iris.csv')

# %%
data1=pd.DataFrame(data)

# %%
data1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data1.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the Dataset

# %%
data=pd.read_csv('D:\python programming\_data\iris.csv')

# %%
data1=pd.DataFrame(data)

# %%
data1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data1.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
#total number of null values
data1.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring atleast 3 .

# %%
data1['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # i. Countplot

# %%
sns.countplot(x='species',data=data1)
plt.show()

# %% [markdown]
# # ii. Boxplot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.boxplot(x='species',y='sepal_length',data=data1)
plt.subplot(2,2,2)
sns.boxplot(x='species',y='sepal_width',data=data1)
plt.subplot(2,2,3)
sns.boxplot(x='species',y='petal_length',data=data1)
plt.subplot(2,2,4)
sns.boxplot(x='species',y='petal_width',data=data1)
pass

# %% [markdown]
# # iii. Stripplot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.stripplot(x=data['species'],y=data['sepal_length'],data=data1,hue='species')
plt.subplot(2,2,2)
sns.stripplot(x=data['species'],y=data['sepal_width'],data=data1,hue='species')
plt.subplot(2,2,3)
sns.stripplot(x=data['species'],y=data['petal_length'],data=data1,hue='species')
plt.subplot(2,2,4)
sns.stripplot(x=data['species'],y=data['petal_width'],data=data1,hue='species')
pass

# %% [markdown]
# # iv. Heatmap

# %%
sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'sepal_length'),
#   Text(1.5, 0, 'sepal_width'),
#   Text(2.5, 0, 'petal_length'),
#   Text(3.5, 0, 'petal_width')])

# %% [markdown]
# # v. Violinplot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length',data=data1)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width',data=data1)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length',data=data1)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width',data=data1)
pass
